# %%
import os
import pyecharts
import datetime
import pandas as pd
import numpy as np


# 全局  当前周(实际为上周) / 当前月 / 上一个月
currentWeek = 50
currentMonth = 12
lastMonth = 11

# %%
data= [{'keyword': '失业金', 'type': 'all', 'date': '2011-01-01', 'index': '61'}, 
       {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-01', 'index': '61'}, 
       {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-01', 'index': '0'}, 
       {'keyword': '失业金', 'type': 'all', 'date': '2011-01-02', 'index': '59'}, 
       {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-02', 'index': '59'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-02', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-03', 'index': '57'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-03', 'index': '57'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-03', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-04', 'index': '61'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-04', 'index': '61'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-04', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-05', 'index': '64'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-05', 'index': '64'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-05', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-06', 'index': '66'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-06', 'index': '66'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-06', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-07', 'index': '59'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-07', 'index': '59'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-07', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-08', 'index': '59'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-08', 'index': '59'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-08', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-09', 'index': '64'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-09', 'index': '64'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-09', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-10', 'index': '66'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-10', 'index': '66'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-10', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-11', 'index': '64'}, 
       
       {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-11', 'index': '64'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-11', 'index': '0'}, 
       
       {'keyword': '失业金', 'type': 'all', 'date': '2011-01-12', 'index': '57'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-12', 'index': '57'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-12', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-13', 'index': '57'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-13', 'index': '57'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-13', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-14', 'index': '63'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-14', 'index': '63'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-14', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-15', 'index': '57'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-15', 'index': '57'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-15', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-16', 'index': '57'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-16', 'index': '57'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-16', 'index': '0'}, 
       {'keyword': '失业金', 'type': 'all', 'date': '2011-01-17', 'index': '74'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-17', 'index': '74'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-17', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-18', 'index': '59'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-18', 'index': '59'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-18', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-19', 'index': '59'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-19', 'index': '59'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-19', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-20', 'index': '57'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-20', 'index': '57'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-20', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-21', 'index': '64'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-21', 'index': '64'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-21', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-22', 'index': '59'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-22', 'index': '59'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-22', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-23', 'index': '59'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-23', 'index': '59'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-23', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-24', 'index': '64'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-24', 'index': '64'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-24', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-25', 'index': '57'},
       {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-25', 'index': '57'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-25', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-26', 'index': '66'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-26', 'index': '66'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-26', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-27', 'index': '63'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-27', 'index': '63'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-27', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-28', 'index': '61'}, 
       {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-28', 'index': '61'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-28', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-29', 'index': '59'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-29', 'index': '59'},
       {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-29', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-01-30', 'index': '59'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-30', 'index': '59'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-30', 'index': '0'},
       {'keyword': '失业金', 'type': 'all', 'date': '2011-01-31', 'index': '57'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-01-31', 'index': '57'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-01-31', 'index': '0'}, {'keyword': '失业金', 'type': 'all', 'date': '2011-02-01', 'index': '57'}, {'keyword': '失业金', 'type': 'pc', 'date': '2011-02-01', 'index': '57'}, {'keyword': '失业金', 'type': 'wise', 'date': '2011-02-01', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-01', 'index': '440'}, 
       {'keyword': '股票', 'type': 'pc', 'date': '2011-01-01', 'index': '440'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-01', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-02', 'index': '405'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-02', 'index': '405'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-02', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-03', 'index': '222'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-03', 'index': '222'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-03', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-04', 'index': '461'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-04', 'index': '461'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-04', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-05', 'index': '642'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-05', 'index': '642'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-05', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-06', 'index': '630'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-06', 'index': '630'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-06', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-07', 'index': '408'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-07', 'index': '408'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-07', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-08', 'index': '212'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-08', 'index': '212'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-08', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-09', 'index': '211'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-09', 'index': '211'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-09', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-10', 'index': '447'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-10', 'index': '447'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-10', 'index': '0'},
       
       {'keyword': '股票', 'type': 'all', 'date': '2011-01-11', 'index': '561'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-11', 'index': '561'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-11', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-12', 'index': '616'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-12', 'index': '616'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-12', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-13', 'index': '582'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-13', 'index': '582'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-13', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-14', 'index': '574'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-14', 'index': '574'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-14', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-15', 'index': '186'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-15', 'index': '186'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-15', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-16', 'index': '183'}, 
       {'keyword': '股票', 'type': 'pc', 'date': '2011-01-16', 'index': '183'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-16', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-17', 'index': '406'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-17', 'index': '406'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-17', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-18', 'index': '352'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-18', 'index': '352'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-18', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-19', 'index': '405'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-19', 'index': '405'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-19', 'index': '0'},
       
       {'keyword': '股票', 'type': 'all', 'date': '2011-01-20', 'index': '397'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-20', 'index': '397'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-20', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-21', 'index': '372'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-21', 'index': '372'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-21', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-22', 'index': '155'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-22', 'index': '155'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-22', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-23', 'index': '188'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-23', 'index': '188'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-23', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-24', 'index': '313'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-24', 'index': '313'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-24', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-25', 'index': '343'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-25', 'index': '343'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-25', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-26', 'index': '318'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-26', 'index': '318'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-26', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-27', 'index': '366'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-27', 'index': '366'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-27', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-28', 'index': '377'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-28', 'index': '377'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-28', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-29', 'index': '179'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-29', 'index': '179'}, 
       
       {'keyword': '股票', 'type': 'wise', 'date': '2011-01-29', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-30', 'index': '197'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-30', 'index': '197'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-30', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-01-31', 'index': '301'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-01-31', 'index': '301'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-01-31', 'index': '0'}, {'keyword': '股票', 'type': 'all', 'date': '2011-02-01', 'index': '251'}, {'keyword': '股票', 'type': 'pc', 'date': '2011-02-01', 'index': '251'}, {'keyword': '股票', 'type': 'wise', 'date': '2011-02-01', 'index': '0'}]

df = pd.DataFrame(data=data)

# %%
df.pivot_table(columns='type')
# Out:
#            date index keyword  type
# 0    2011-01-01    61     失业金   all
# 1    2011-01-01    61     失业金    pc
# 2    2011-01-01     0     失业金  wise
# 3    2011-01-02    59     失业金   all
# 4    2011-01-02    59     失业金    pc
# 5    2011-01-02     0     失业金  wise
# 6    2011-01-03    57     失业金   all
# 7    2011-01-03    57     失业金    pc
# 8    2011-01-03     0     失业金  wise
# 9    2011-01-04    61     失业金   all
# 10   2011-01-04    61     失业金    pc
# 11   2011-01-04     0     失业金  wise
# 12   2011-01-05    64     失业金   all
# 13   2011-01-05    64     失业金    pc
# 14   2011-01-05     0     失业金  wise
# 15   2011-01-06    66     失业金   all
# 16   2011-01-06    66     失业金    pc
# 17   2011-01-06     0     失业金  wise
# 18   2011-01-07    59     失业金   all
# 19   2011-01-07    59     失业金    pc
# 20   2011-01-07     0     失业金  wise
# 21   2011-01-08    59     失业金   all
# 22   2011-01-08    59     失业金    pc
# 23   2011-01-08     0     失业金  wise
# 24   2011-01-09    64     失业金   all
# ...
